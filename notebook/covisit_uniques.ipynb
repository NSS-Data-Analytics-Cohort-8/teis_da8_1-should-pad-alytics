# %% [markdown]
# What is the rate of telehealth versus other services? (graph)
# Is telehealth used for a specific type of FSP Teaming ID Name? (Bar graph)
# What is the rate of co-visits that are telehealth? (Pie Chart)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel('../data/TEIS_IFSP_Teaming_Jan_2022-_Jan_2023.xlsx', sheet_name='Compiled_IFSP Teaming')
df1
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0     Service Delivered         LEECAROL1 2022-01-21 17:54:45
# 1     Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 2     Service Delivered  MILLARDCATHERINE 2022-01-24 14:18:29
# 3     Service Delivered       HEMELKATIE1 2022-01-18 10:39:51
# 4     Service Delivered        JONESMEGAN 2022-01-12 13:46:48
# ...                 ...               ...                 ...
# 9538  Service Delivered           WESTAMY 2023-01-12 17:55:59
# 9539  Service Delivered           WESTAMY 2023-01-20 16:11:04
# 9540  Service Delivered           WESTAMY 2023-01-20 10:23:05
# 9541  Service Delivered   FANELLASAMANTHA 2023-01-30 15:21:59
# 9542  Service Delivered        QUINNEMILY 2023-02-02 21:54:53
#
#      IFSP Teaming ID name                         Agency Name Agency Type  \
# 0             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 1                Co-Visit  Siskin Children's Institute (EIRA)        EIRA
# 2             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 3             IEP Meeting                               LTVEC        EIRA
# 4            IFSP Meeting             First Steps, Inc (EIRA)        EIRA
# ...                   ...                                 ...         ...
# 9538             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9539             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9540             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9541         IFSP Meeting           Pediatric Language Clinic        EIRA
# 9542             Co-Visit  Little Folks Arc of Washington Co.        EIRA
#
#                             Service Name
# 0     Dev. Therapy Prof - Home/Community
# 1     Dev. Therapy Prof - Home/Community
# 2     Dev. Therapy Prof - Home/Community
# 3     Dev. Therapy Prof - Home/Community
# 4     Dev. Therapy Prof - Home/Community
# ...                                  ...
# 9538  Dev. Therapy Prof - Home/Community
# 9539  Dev. Therapy Prof - Home/Community
# 9540  Dev. Therapy Prof - Home/Community
# 9541  Dev. Therapy Prof - Home/Community
# 9542  Dev. Therapy Prof - Home/Community
#
# [9543 rows x 12 columns]

# %%
df2 = pd.read_excel('../data/TEIS_IFSP_Teaming_Jan_2022-_Jan_2023.xlsx', sheet_name='All Children with IFSPs')
# Out:
# C:\Users\scost\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
co_times = df1[(df1['IFSP Teaming ID name'] == 'Co-Visit') & (df1['SERVICE DELIVERY'] == 'Service Delivered')]
co_times
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 6       458850   2022-02-15   14:00:00  14:30:00       Telehealth
# 7       458851   2022-02-15   14:15:00  14:45:00       Telehealth
# 8       459167   2022-01-26   09:30:00  10:00:00       Telehealth
# 9       459167   2022-01-26   09:00:00  10:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9537    540954   2023-01-27   10:35:00  11:33:00            Other
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY        ADD_USER            ADD_DATE  \
# 1     Service Delivered       LEECAROL1 2022-02-16 05:29:12
# 6     Service Delivered     BUCKCYNTHIA 2022-02-15 18:07:38
# 7     Service Delivered     BUCKCYNTHIA 2022-02-15 18:08:54
# 8     Service Delivered  HINESKONSTANCE 2022-01-26 11:08:06
# 9     Service Delivered  GLASSKATHERINE 2022-02-02 11:57:55
# ...                 ...             ...                 ...
# 9537  Service Delivered  SPRADLINGSARAH 2023-01-27 15:21:18
# 9538  Service Delivered         WESTAMY 2023-01-12 17:55:59
# 9539  Service Delivered         WESTAMY 2023-01-20 16:11:04
# 9540  Service Delivered         WESTAMY 2023-01-20 10:23:05
# 9542  Service Delivered      QUINNEMILY 2023-02-02 21:54:53
#
#      IFSP Teaming ID name                           Agency Name  Agency Type  \
# 1                Co-Visit    Siskin Children's Institute (EIRA)         EIRA
# 6                Co-Visit  Physical Therapy Services, PA (EIRA)         EIRA
# 7                Co-Visit  Physical Therapy Services, PA (EIRA)         EIRA
# 8                Co-Visit      LeBonheur EI & Dev (LEAD) (EIRA)         EIRA
# 9                Co-Visit    LeBonheur EI & Dev (LEAD) (vendor)  Independent
# ...                   ...                                   ...          ...
# 9537             Co-Visit     Rainbow Early Intervention (HATS)         EIRA
# 9538             Co-Visit                    Kid's Putnam, Inc.         EIRA
# 9539             Co-Visit                    Kid's Putnam, Inc.         EIRA
# 9540             Co-Visit                    Kid's Putnam, Inc.         EIRA
# 9542             Co-Visit    Little Folks Arc of Washington Co.         EIRA
#
#                             Service Name
# 1     Dev. Therapy Prof - Home/Community
# 6     Dev. Therapy Prof - Home/Community
# 7     Dev. Therapy Prof - Home/Community
# 8             Physical Therapy Assistant
# 9                         Speech Therapy
# ...                                  ...
# 9537  Dev. Therapy Prof - Home/Community
# 9538  Dev. Therapy Prof - Home/Community
# 9539  Dev. Therapy Prof - Home/Community
# 9540  Dev. Therapy Prof - Home/Community
# 9542  Dev. Therapy Prof - Home/Community
#
# [4087 rows x 12 columns]

# %%
#Count of co_visits based on unique dates by child
new_count = co_times.groupby("CHILD_ID")["SERVICE_DATE"].nunique().reset_index(name="co_visits_counts")
num_co_visits = new_count['co_visits_counts'].sum()
num_co_visits
# Out:
# 3552

# %%
new_count
# Out:
#       CHILD_ID  co_visits_counts
# 0       457136                 1
# 1       458850                 1
# 2       458851                 1
# 3       459167                 2
# 4       459566                 1
# ...        ...               ...
# 1637    540954                 1
# 1638    541337                 1
# 1639    541511                 1
# 1640    541890                 1
# 1641    542122                 1
#
# [1642 rows x 2 columns]

# %%
telehealth_data = df1[(df1['SERVICE_SETTING'] == 'Telehealth') & (df1['SERVICE DELIVERY'] == 'Service Delivered')]
unique_telehealth_data = telehealth_data.drop_duplicates(subset=['CHILD_ID','SERVICE_DATE'])
fsp_count = unique_telehealth_data['IFSP Teaming ID name'].value_counts()
fsp_count
# Out:
# IFSP Meeting    2461
# Co-Visit         713
# IEP Meeting      357
# Name: IFSP Teaming ID name, dtype: int64

# %% [markdown]
#  What is the rate of co-visits that are telehealth?

# %%
df1
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0     Service Delivered         LEECAROL1 2022-01-21 17:54:45
# 1     Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 2     Service Delivered  MILLARDCATHERINE 2022-01-24 14:18:29
# 3     Service Delivered       HEMELKATIE1 2022-01-18 10:39:51
# 4     Service Delivered        JONESMEGAN 2022-01-12 13:46:48
# ...                 ...               ...                 ...
# 9538  Service Delivered           WESTAMY 2023-01-12 17:55:59
# 9539  Service Delivered           WESTAMY 2023-01-20 16:11:04
# 9540  Service Delivered           WESTAMY 2023-01-20 10:23:05
# 9541  Service Delivered   FANELLASAMANTHA 2023-01-30 15:21:59
# 9542  Service Delivered        QUINNEMILY 2023-02-02 21:54:53
#
#      IFSP Teaming ID name                         Agency Name Agency Type  \
# 0             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 1                Co-Visit  Siskin Children's Institute (EIRA)        EIRA
# 2             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 3             IEP Meeting                               LTVEC        EIRA
# 4            IFSP Meeting             First Steps, Inc (EIRA)        EIRA
# ...                   ...                                 ...         ...
# 9538             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9539             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9540             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9541         IFSP Meeting           Pediatric Language Clinic        EIRA
# 9542             Co-Visit  Little Folks Arc of Washington Co.        EIRA
#
#                             Service Name
# 0     Dev. Therapy Prof - Home/Community
# 1     Dev. Therapy Prof - Home/Community
# 2     Dev. Therapy Prof - Home/Community
# 3     Dev. Therapy Prof - Home/Community
# 4     Dev. Therapy Prof - Home/Community
# ...                                  ...
# 9538  Dev. Therapy Prof - Home/Community
# 9539  Dev. Therapy Prof - Home/Community
# 9540  Dev. Therapy Prof - Home/Community
# 9541  Dev. Therapy Prof - Home/Community
# 9542  Dev. Therapy Prof - Home/Community
#
# [9543 rows x 12 columns]

# %%
telehealth_data = df1[(df1['SERVICE_SETTING'] == 'Telehealth') & (df1['SERVICE DELIVERY'] == 'Service Delivered')]
unique_telehealth_data = telehealth_data.drop_duplicates(subset=['CHILD_ID','SERVICE_DATE'])
fsp_count = unique_telehealth_data['IFSP Teaming ID name'].value_counts()
fsp_count
# Out:
# IFSP Meeting    2461
# Co-Visit         713
# IEP Meeting      357
# Name: IFSP Teaming ID name, dtype: int64

# %% [markdown]
# the code above is not what we want

# %%
df_telehealth = df1[df1['SERVICE_SETTING'] == 'Telehealth']
df3 = df_telehealth.groupby(['CHILD_ID', 'SERVICE_DATE', 'START_TIME', 'IFSP Teaming ID name']).size().reset_index(name='Count')
total_count = df3.groupby(['IFSP Teaming ID name']).size().reset_index(name='Total Count')

# Calculate the total count of all three combined
total_all_combined = total_count['Total Count'].sum()

# Create a new row with the total count of all three combined
total_combined_row = pd.DataFrame({'IFSP Teaming ID name': ['Total'], 'Total Count': [total_all_combined]})
total_count = pd.concat([total_count, total_combined_row], ignore_index=True)
total_count
# Out:
#   IFSP Teaming ID name  Total Count
# 0             Co-Visit          729
# 1          IEP Meeting          359
# 2         IFSP Meeting         2462
# 3                Total         3550

# %%
df1
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0     Service Delivered         LEECAROL1 2022-01-21 17:54:45
# 1     Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 2     Service Delivered  MILLARDCATHERINE 2022-01-24 14:18:29
# 3     Service Delivered       HEMELKATIE1 2022-01-18 10:39:51
# 4     Service Delivered        JONESMEGAN 2022-01-12 13:46:48
# ...                 ...               ...                 ...
# 9538  Service Delivered           WESTAMY 2023-01-12 17:55:59
# 9539  Service Delivered           WESTAMY 2023-01-20 16:11:04
# 9540  Service Delivered           WESTAMY 2023-01-20 10:23:05
# 9541  Service Delivered   FANELLASAMANTHA 2023-01-30 15:21:59
# 9542  Service Delivered        QUINNEMILY 2023-02-02 21:54:53
#
#      IFSP Teaming ID name                         Agency Name Agency Type  \
# 0             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 1                Co-Visit  Siskin Children's Institute (EIRA)        EIRA
# 2             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 3             IEP Meeting                               LTVEC        EIRA
# 4            IFSP Meeting             First Steps, Inc (EIRA)        EIRA
# ...                   ...                                 ...         ...
# 9538             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9539             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9540             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9541         IFSP Meeting           Pediatric Language Clinic        EIRA
# 9542             Co-Visit  Little Folks Arc of Washington Co.        EIRA
#
#                             Service Name
# 0     Dev. Therapy Prof - Home/Community
# 1     Dev. Therapy Prof - Home/Community
# 2     Dev. Therapy Prof - Home/Community
# 3     Dev. Therapy Prof - Home/Community
# 4     Dev. Therapy Prof - Home/Community
# ...                                  ...
# 9538  Dev. Therapy Prof - Home/Community
# 9539  Dev. Therapy Prof - Home/Community
# 9540  Dev. Therapy Prof - Home/Community
# 9541  Dev. Therapy Prof - Home/Community
# 9542  Dev. Therapy Prof - Home/Community
#
# [9543 rows x 12 columns]

# %%
# Filter dataframe for covisits classified as telehealth
df_telehealth = df1[df1['SERVICE_SETTING'] == 'Telehealth']

# Group by CHILD_ID, SERVICE_DATE, START_TIME, and IFSP Teaming ID name, and count the occurrences
df3 = df_telehealth.groupby(['CHILD_ID', 'SERVICE_DATE', 'START_TIME', 'IFSP Teaming ID name']).size().reset_index(name='Count')

# Calculate the total count for each IFSP Teaming ID name
total_count = df3.groupby(['IFSP Teaming ID name']).size().reset_index(name='Total Count')

# Calculate the total count of all three combined
total_all_combined = total_count['Total Count'].sum()

# Calculate the rate of telehealth covisits (co-visits)
rate_telehealth_covisits = total_count[total_count['IFSP Teaming ID name'] == 'Co-Visit']['Total Count'].values[0] / total_all_combined * 100

print("Rate of telehealth covisits (co-visits): {:.2f}%".format(rate_telehealth_covisits))
# Out:
# Rate of telehealth covisits (co-visits): 20.54%

# %%
labels = ['Telehealth', 'Other IFSP Teaming IDs']
sizes = [rate_telehealth_covisits, 100 - rate_telehealth_covisits]
colors = [ "#EF412A", "#7099E9"]
explode = (0.1, 0)  # Explode the first slice (Telehealth Covisits) for emphasis

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%.2f%%', startangle=90, shadow=False)

# Remove the legend
plt.legend().set_visible(False)


plt.axis('equal')  # Ensure the pie chart is circular
plt.show()

# %%
# Sort in descending order
total_count_sorted = total_count.sort_values('Total Count', ascending=False)

colors = ["#6E99EC", "#415A8C", "#EF412A", "#C7CAD5"]

# Calculate the total count
total_count_sum = total_count_sorted['Total Count'].sum()

# Create a DataFrame for the total count
total_df = pd.DataFrame({'IFSP Teaming ID name': ['Total'], 'Total Count': [total_count_sum]})

# Concatenate the total DataFrame with the sorted DataFrame
combined_df = pd.concat([total_df, total_count_sorted])

# Increase the figure size
plt.figure(figsize=(12, 8))

# Plot the bar chart with adjusted bar width and no edgecolor
bars = sns.barplot(x=combined_df['IFSP Teaming ID name'], y=combined_df['Total Count'], palette=colors, linewidth=1.5, edgecolor=None)


# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Remove labels
plt.xlabel('')
plt.ylabel('')

# Add data labels to the bars
for i, count in enumerate(combined_df['Total Count']):
    plt.text(i, count + 1, str(count), ha='center', va='bottom', fontsize=10)

# Remove the top and right spines
sns.despine()

plt.tight_layout()
plt.show()
